# %% [markdown]
# # ICP01 Jupyter Install
# ## Anil Babu Davuluri

# %% [markdown]
# ![DSP image.jpg](attachment:8ae58191-921f-4794-af8b-7994afa03813.jpg)
# ### I am Anil Babu Davuluri,from india and a graduate student of Business Analytics and Information Systems in MUMA School of Business-University of South Florida.My hobbies are running, reading and writing.

# %%
print('Hello World')
# Out:
# Hello World
